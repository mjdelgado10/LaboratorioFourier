# %%
import pandas as pd

# %%
archivo=pd.read_csv("https://raw.githubusercontent.com/ComputoCienciasUniandes/FISI2029-201910/master/Seccion_1/Fourier/Datos/transacciones2008.txt",sep=";", header=None, names=[ "a" , "b","c", "d" ] )
archivo["a"] = archivo["a"].astype(str).str[0:-8]
archivo["b"] = archivo["b"].astype(str).str[-8:]  
print(archivo)
#print(archivo)
# Out:
#                  a         b       c           d
# 0         2/1/2008   8:49:33  499,00   500000,00
# 1         2/1/2008   8:49:40  499,00   500000,00
# 2         2/1/2008   8:49:58  499,00   100000,00
# 3         2/1/2008   8:50:09  499,00   250000,00
# 4         2/1/2008   8:50:17  499,40   200000,00
# 5         2/1/2008   8:50:20  499,49   500000,00
# 6         2/1/2008   8:50:26  499,50   500000,00
# 7         2/1/2008   8:50:26  499,00   200000,00
# 8         2/1/2008   8:50:34  499,49   500000,00
# 9         2/1/2008   8:51:00  499,80   200000,00
# 10        2/1/2008   8:54:25  499,50   250000,00
# 11        2/1/2008   8:55:12  499,10  1000000,00
# 12        2/1/2008   8:55:40  499,30   150000,00
# 13        2/1/2008   8:55:57  499,10   200000,00
# 14        2/1/2008   8:56:10  498,90   200000,00
# 15        2/1/2008   8:56:13  498,85  1000000,00
# 16        2/1/2008   8:57:02  498,75   100000,00
# 17        2/1/2008   8:57:06  498,70  1000000,00
# ...

# %%
archivo2=pd.read_csv("https://raw.githubusercontent.com/ComputoCienciasUniandes/FISI2029-201910/master/Seccion_1/Fourier/Datos/transacciones2009.txt",sep=";", header=None, names=[ "a" , "b","c", "d" ])
archivo2["a"] = archivo2["a"].astype(str).str[0:-8]
archivo2["b"] = archivo2["b"].astype(str).str[-8:] 
print(archivo2)
# Out:
#                  a         b       c           d
# 0         2/1/2009   8:47:06  640,00   250000,00
# 1         2/1/2009   8:51:37  639,00   500000,00
# 2         2/1/2009   8:53:04  639,50   500000,00
# 3         2/1/2009   8:53:09  639,90   500000,00
# 4         2/1/2009   8:53:19  639,90   500000,00
# 5         2/1/2009   8:53:21  639,90   500000,00
# 6         2/1/2009   8:53:54  640,90   100000,00
# 7         2/1/2009   8:56:33  641,20   100000,00
# 8         2/1/2009   8:56:59  641,50   171000,00
# 9         2/1/2009   8:57:02  641,20   150000,00
# 10        2/1/2009   8:57:03  641,15   100000,00
# 11        2/1/2009   8:58:06  641,00   100000,00
# 12        2/1/2009   8:58:16  641,00   300000,00
# 13        2/1/2009   8:58:34  640,22   100000,00
# 14        2/1/2009   9:00:02  640,15   571000,00
# 15        2/1/2009   9:00:03  640,15   500000,00
# 16        2/1/2009   9:02:00  641,00   150000,00
# 17        2/1/2009   9:02:01  641,00   150000,00
# ...

# %%
archivo3=pd.read_csv("https://raw.githubusercontent.com/ComputoCienciasUniandes/FISI2029-201910/master/Seccion_1/Fourier/Datos/transacciones2010.txt",sep=";", header=None, names=[ "a" , "b","c", "d" ])
archivo3["a"] = archivo3["a"].astype(str).str[0:-8]
archivo3["b"] = archivo3["b"].astype(str).str[-8:] 
print(archivo3)
# Out:
#                  a         b       c           d
# 0         4/1/2010   8:39:36  505,00   100000,00
# 1         4/1/2010   8:40:47  505,50   300000,00
# 2         4/1/2010   8:52:24  505,50   281000,00
# 3         4/1/2010   8:52:27  505,75   200000,00
# 4         4/1/2010   8:59:11  505,80   100000,00
# 5         4/1/2010   8:59:37  505,95   300000,00
# 6         4/1/2010   8:59:57  505,95   200000,00
# 7         4/1/2010   9:00:19  505,70   500000,00
# 8         4/1/2010   9:00:26  505,65   300000,00
# 9         4/1/2010   9:00:38  505,50   500000,00
# 10        4/1/2010   9:01:00  505,50   500000,00
# 11        4/1/2010   9:02:08  505,60   500000,00
# 12        4/1/2010   9:02:21  505,68   200000,00
# 13        4/1/2010   9:02:22  505,70   200000,00
# 14        4/1/2010   9:02:38  505,75  1000000,00
# 15        4/1/2010   9:02:46  505,70   250000,00
# 16        4/1/2010   9:03:52  505,80   700000,00
# 17        4/1/2010   9:03:57  506,00   500000,00
# ...

# %%
pd.concat([archivo,archivo2,archivo3])
# Out:
#                  a         b       c           d
# 0         2/1/2008   8:49:33  499,00   500000,00
# 1         2/1/2008   8:49:40  499,00   500000,00
# 2         2/1/2008   8:49:58  499,00   100000,00
# 3         2/1/2008   8:50:09  499,00   250000,00
# 4         2/1/2008   8:50:17  499,40   200000,00
# 5         2/1/2008   8:50:20  499,49   500000,00
# 6         2/1/2008   8:50:26  499,50   500000,00
# 7         2/1/2008   8:50:26  499,00   200000,00
# 8         2/1/2008   8:50:34  499,49   500000,00
# 9         2/1/2008   8:51:00  499,80   200000,00
# 10        2/1/2008   8:54:25  499,50   250000,00
# 11        2/1/2008   8:55:12  499,10  1000000,00
# 12        2/1/2008   8:55:40  499,30   150000,00
# 13        2/1/2008   8:55:57  499,10   200000,00
# 14        2/1/2008   8:56:10  498,90   200000,00
# 15        2/1/2008   8:56:13  498,85  1000000,00
# 16        2/1/2008   8:57:02  498,75   100000,00
# 17        2/1/2008   8:57:06  498,70  1000000,00
# ...
